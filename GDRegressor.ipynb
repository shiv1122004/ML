# %% [markdown]
# <a href="https://colab.research.google.com/github/shiv1122004/ML/blob/main/GDRegressor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x,y=make_regression(n_samples=100,n_features=1,n_informative=1,n_targets=1,noise=20)

# %%
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [28.88657065]
# 1.0626819428690597

# %%
m=28.88657065

# %%
class GDRegressor:
  def __init__(self,le):
